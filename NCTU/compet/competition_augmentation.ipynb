# %%
pathim="train_images/"
pathlbl="train.csv"

imnb=2527

#label
#0 : all
#1 : all
#2 : no rotate (or only 180)
#3 : no rotate (or only 180)
#4 : no rotate (or only 180)
#5 : all

# %%
def get_fname(file_nb):
    return pathim+"train_"+(5-len(str(file_nb)))*'0'+str(file_nb)+".png"

def rotate(img,angle=90):
    import numpy as np
    rot=int(angle/90)
    for i in range(rot):
        img = np.transpose(img)
    return img

def brightness(img,bright=1):
    #img2=img+img*(-1+bright)
    img2=img+bright
    #img2=bright*img
    return img2

def mirror(img,axe='h'):
    import numpy as np
    img2=np.copy(img)
    if axe=='v':
        n=img.shape[1]
        for i in range(n//2):
            img2[:,i]=img[:,n-i-1]
            img2[:,n-i-1]=img[:,i]
    else:
        n=img.shape[0]
        for i in range(n//2):
            img2[i,:]=img[n-i-1,:]
            img2[n-i-1,:]=img[i,:]
    return img2

# %% [markdown]
# # perform

# %%
# %%time
import shutil
import os
import matplotlib.pyplot as plt
import imageio

try:
    os.mkdir("data_augment")
except:
    print("data_augment already exist")
try:
    os.mkdir("data_augment/normal")
except:
    print("data_augment/normal already exist")
try:
    os.mkdir("data_augment/rotate")
except:
    print("data_augment/rotate already exist")
try:
    os.mkdir("data_augment/brightness")
except:
    print("data_augment/brightness already exist")
try:
    os.mkdir("data_augment/mirror")
except:
    print("data_augment/mirror already exist")
    
f=open(pathlbl,"r")
labels=f.readlines()
f.close()

#for mirror
axe=['h','v']
f=open("data_augment/train_m.csv","w")
f.write("ID,Label\n")
f.close()

#for brightness
f=open("data_augment/train_b.csv","w")
f.write("ID,Label\n")
f.close()

#for rotate
proh=[2,3,4]
angle=[90,180,270]
itr=0
f=open("data_augment/train_r.csv","w")
f.write("ID,Label\n")
f.close()

#for normal
f=open("data_augment/train_n.csv","w")
f.write("ID,Label\n")
f.close()

for i in range(0,imnb+1):
    lbl=int(labels[i+1][16])
    imname=labels[i+1][:15]
    img=plt.imread(pathim+imname)
    
    #mirror
    p_m=axe[i%2]
    imname_m=imname[:11]+"_m"+".png"
    img_m=mirror(img,axe=p_m)
    imageio.imwrite("data_augment/mirror/"+imname_m,img_m)
    f=open("data_augment/train_m.csv","a")
    f.write(imname_m+","+str(lbl)+"\n")
    f.close()
    
    #brightness
    imname_b=imname[:11]+"_b"+".png"
    img_b=brightness(img)
    imageio.imwrite("data_augment/brightness/"+imname_b,img_b)
    f=open("data_augment/train_b.csv","a")
    f.write(imname_b+","+str(lbl)+"\n")
    f.close()
    
    #rotate
    if lbl in proh:
        p_r=180
    else:
        p_r=angle[itr%3]
        itr+=1
    imname_r=imname[:11]+"_r"+".png"
    img_r=rotate(img,angle=p_r)
    imageio.imwrite("data_augment/rotate/"+imname_r,img_r)
    f=open("data_augment/train_r.csv","a")
    f.write(imname_r+","+str(lbl)+"\n")
    f.close()
    
    #normal
    shutil.copy(pathim+imname,"data_augment/normal/"+imname)
    f=open("data_augment/train_n.csv","a")
    f.write(imname+","+str(lbl)+"\n")
    f.close()
# Out:
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4274510145187378, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4509804248809814, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5568628311157227, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4313725233078003, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5098040103912354, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.384313702583313, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3686274290084839, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.529411792755127, 1.756862759590149]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.243137240409851, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2705882787704468, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3411765098571777, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4823529720306396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3607842922210693, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3372548818588257, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5137255191802979, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.458823561668396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.458823561668396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3960784673690796, 1.933333396911621]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2470588684082031, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4274510145187378, 1.9450980424880981]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.6588234901428223, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3333333730697632, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4823529720306396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3803921937942505, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.372549057006836, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5058823823928833, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4156862497329712, 1.9921568632125854]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4392156600952148, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2549020051956177, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4078431129455566, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5215686559677124, 1.7882353067398071]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4509804248809814, 1.77647066116333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4784313440322876, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3568627834320068, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.372549057006836, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.619607925415039, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4509804248809814, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5411765575408936, 1.9803922176361084]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4666666984558105, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2784314155578613, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5333333015441895, 1.8901960849761963]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4313725233078003, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5058823823928833, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4274510145187378, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3450980186462402, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3607842922210693, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4941176176071167, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3686274290084839, 1.8274509906768799]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2745097875595093, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.443137288093567, 1.8549020290374756]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2509803771972656, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4078431129455566, 1.917647123336792]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4784313440322876, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4352941513061523, 1.901960849761963]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4078431129455566, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4039216041564941, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4196078777313232, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4078431129455566, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3058823347091675, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.458823561668396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4274510145187378, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.545098066329956, 1.7529411315917969]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5098040103912354, 1.9725489616394043]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.470588207244873, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.458823561668396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3647059202194214, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4196078777313232, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5529412031173706, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4313725233078003, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3529411554336548, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3686274290084839, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.470588207244873, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3529411554336548, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4196078777313232, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4941176176071167, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3490196466445923, 1.909803867340088]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5176470279693604, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4901961088180542, 1.8156862258911133]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4901961088180542, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 1.8117647171020508]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5490195751190186, 1.8196078538894653]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.474509835243225, 1.8352941274642944]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5176470279693604, 1.8274509906768799]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.454901933670044, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.384313702583313, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3803921937942505, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3764705657958984, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4352941513061523, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4039216041564941, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5254902839660645, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4156862497329712, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4980392456054688, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.399999976158142, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.301960825920105, 1.858823537826538]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4235293865203857, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5215686559677124, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3607842922210693, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3529411554336548, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4784313440322876, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3686274290084839, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5254902839660645, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4823529720306396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4352941513061523, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2862745523452759, 1.768627405166626]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.458823561668396, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3529411554336548, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4980392456054688, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4901961088180542, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3215686082839966, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4392156600952148, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.384313702583313, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3921568393707275, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.443137288093567, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4078431129455566, 1.9764705896377563]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.317647099494934, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4862744808197021, 1.7058823108673096]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.372549057006836, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4901961088180542, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.384313702583313, 1.917647123336792]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.1843137741088867, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.317647099494934, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.474509835243225, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5490195751190186, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.454901933670044, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.611764669418335, 1.984313726425171]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3568627834320068, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2823529243469238, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4117647409439087, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4392156600952148, 1.9921568632125854]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4901961088180542, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4980392456054688, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.443137288093567, 1.9568626880645752]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4470587968826294, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.474509835243225, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5411765575408936, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5490195751190186, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4509804248809814, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4509804248809814, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3254902362823486, 1.8941175937652588]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3215686082839966, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.443137288093567, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4509804248809814, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3098039627075195, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3450980186462402, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.470588207244873, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4862744808197021, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3921568393707275, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.529411792755127, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3764705657958984, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.2392157316207886, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3764705657958984, 1.9921568632125854]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.470588207244873, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.388235330581665, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4470587968826294, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3686274290084839, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.317647099494934, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3607842922210693, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.627450942993164, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4941176176071167, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4627450704574585, 1.8235294818878174]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.5098040103912354, 1.8235294818878174]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.1647058725357056, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.3960784673690796, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [1.4666666984558105, 2.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Wall time: 28min 14s

# %%
print("done")
# Out:
# done
